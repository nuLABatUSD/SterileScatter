# %%
"""
Adapted from plot_distribution.ipynb - 10/9/25

"""
# Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import csv


data0 = np.loadtxt(f"outputs/C_values0.csv", delimiter=',')
dataf = np.loadtxt(f"outputs/C_valuesf.csv", delimiter=',')

eps0 = data0[0,:]

C0 = data0[2,:]
Cf = dataf[2,:]

fig, ax = plt.subplots()
ax.plot(eps0,C0,label='initial')
ax.plot(eps0, Cf,label='final')
#plt.title(f"sim_output{i+1}.csv" + " $a_0$=" + str(a[0]) + "--> $a_f$=" + str(round(a[-1],3)))
plt.xlabel('$\\epsilon$')
plt.ylabel('C')
plt.legend()
plt.show()

# %%
eps0
# Out:
# array([1.80835e-02, 9.35146e-02, 2.22177e-01, 3.92672e-01, 5.89852e-01,
#        7.96200e-01, 9.93380e-01, 1.16387e+00, 1.29254e+00, 1.36797e+00,
#        1.38605e+00, 1.39515e+00, 1.40424e+00, 1.41334e+00, 1.42243e+00,
#        1.43153e+00, 1.44062e+00, 1.44972e+00, 1.45881e+00, 1.46791e+00,
#        1.47700e+00, 1.48609e+00, 1.49519e+00, 1.50428e+00, 1.51338e+00,
#        1.52247e+00, 1.53157e+00, 1.54066e+00, 1.54976e+00, 1.55885e+00,
#        1.56795e+00, 1.57704e+00, 1.58614e+00, 1.59523e+00, 1.60433e+00,
#        1.61342e+00, 1.62252e+00, 1.63161e+00, 1.64071e+00, 1.64980e+00,
#        1.65890e+00, 1.66799e+00, 1.67709e+00, 1.68618e+00, 1.69528e+00,
#        1.70437e+00, 1.71346e+00, 1.72256e+00, 1.73165e+00, 1.74075e+00,
#        1.74984e+00, 1.75894e+00, 1.76803e+00, 1.77713e+00, 1.78622e+00,
#        1.79532e+00, 1.80441e+00, 1.81351e+00, 1.82260e+00, 1.83170e+00,
#        1.99582e+00, 2.63905e+00, 3.58099e+00, 4.52293e+00, 5.16617e+00,
# ...
